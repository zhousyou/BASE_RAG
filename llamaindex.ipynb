# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.readers.file import PandasExcelReader, DocxReader


parse_excel = PandasExcelReader()
parse_docx = DocxReader()

file_extractor = {
    ".xlsx": parse_excel,
    ".docx": parse_docx
}

reader = SimpleDirectoryReader(
    "data_test",
    file_extractor=file_extractor
)

documentes = reader.load_data()

# %% [markdown]
# !python -m pip install openpyxl

# %% [markdown]
# !pip install docx2txt

# %% [markdown]
# ## 元数据

# %%
len(documentes)
# Out:
# 7

# %%
from pprint import pprint

for doc in documentes:
    pprint(doc.metadata)
# Out:
# {'creation_date': '2026-01-29',
#  'file_name': '6.协议书填写模板-20221104更新.xlsx',
#  'file_path': '/root/transformer/data_test/6.协议书填写模板-20221104更新.xlsx',
#  'file_size': 19632,
#  'file_type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#  'last_modified_date': '2026-01-28'}
# {'creation_date': '2026-01-29',
#  'file_name': '6.协议书填写模板-20221104更新.xlsx',
#  'file_path': '/root/transformer/data_test/6.协议书填写模板-20221104更新.xlsx',
#  'file_size': 19632,
#  'file_type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#  'last_modified_date': '2026-01-28'}
# {'creation_date': '2026-01-29',
#  'file_name': '6.协议书填写模板-20221104更新.xlsx',
#  'file_path': '/root/transformer/data_test/6.协议书填写模板-20221104更新.xlsx',
#  'file_size': 19632,
#  'file_type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#  'last_modified_date': '2026-01-28'}
# {'creation_date': '2026-01-29',
#  'file_name': '6.协议书填写模板-20221104更新.xlsx',
# ...

# %%
pprint(documentes[0].text)
pprint(documentes[1].text)
# Out:
# ('Unnamed: 0: 办户类型, 不办理户口: 一, 异地办深户: 二, 办理户口: 三, 办理户口.1: 四, 办理户口.2: 五, 办理户口.3: '
#  '六, 办理户口.4: 七, 办理户口.5: 八, 办理户口.6: 九, 办理户口.7: 十, 办理户口.8: 十一, 办理户口.9: 十二\n'
#  'Unnamed: 0: 工作地点, 不办理户口: 不办户，且不是以下工作地点的：\n'
#  '西安户县、西安高新区、商洛、长沙、宁波保税区, 异地办深户: 本地区无办户条件，需办深户：\n'
#  '中山、汕尾、韶关、汕头、桂林、玉溪、贵阳、杭州、宁波奉化、淮安、吉林、承德、大连、安阳、北京、惠州、无为, 办理户口: 深圳坪山, 办理户口.1: '
#  '深圳坑梓, 办理户口.2: 深圳葵涌, 办理户口.3: 深圳宝龙, 办理户口.4: 长沙（经开区）, 办理户口.5: 长沙（雨花区）, 办理户口.6: '
#  '广安, 办理户口.7: 西安、商洛、包头、太原、银川、西宁南川、海东, 办理户口.8: 常州（户口待22年后进一步确认）, 办理户口.9: 合肥\n'
#  'Unnamed: 0: 三方填写信息, 不办理户口: 单位名称：比亚迪股份有限公司  \n'
#  '单位隶属：市科技局\n'
#  '组织机构代码：19231745-8     \n'
#  '单位性质：民营\n'
#  '社会信用代码：91440300192317458F\n'
#  '联系电话：0755-89888888-68666    \n'
#  '联系人：校园招聘小组       \n'
#  '公司邮政编码：518118\n'
#  '通讯地址：深圳市坪山区比亚迪路3009号                                                            '
#  '报到证抬头：不接收             \n'
#  '报到证地址：不接收                \n'
#  '户口迁移地址：不接收\n'
#  '户口迁移原因：不接收       \n'
#  '档案接收单位名称：不接收  \n'
# ...

# %% [markdown]
# !python -m pip install llama-index-readers-web

# %%
from llama_index.readers.web import BeautifulSoupWebReader

web_loader = BeautifulSoupWebReader()
web_docs = web_loader.load_data(urls=["https://cloud.tencent.com/developer/article/2499999?fromSource=gwzcw.9358214.9358214.9358214&utm_medium=cpc&utm_id=gwzcw.9358214.9358214.9358214"])

# %%
len(web_docs)
# Out:
# 1

# %%
pprint(web_docs[0].text)
# Out:
# ('玩真的！人人有礼！@你的 AI 编码搭子，满血开发拿鹅厂周边~-腾讯云开发者社区-腾讯云腾讯云代码助手 CodeBuddy玩真的！人人有礼！@你的 AI '
#  '编码搭子，满血开发拿鹅厂周边~原创关注作者腾讯云开发者社区文档建议反馈控制台登录/注册首页学习活动专区圈层工具MCP广场文章/答案/技术大牛搜索搜索关闭发布腾讯云代码助手 '
#  'CodeBuddy社区首页 >专栏 >玩真的！人人有礼！@你的 AI 编码搭子，满血开发拿鹅厂周边~玩真的！人人有礼！@你的 AI '
#  '编码搭子，满血开发拿鹅厂周边~原创腾讯云代码助手 CodeBuddy关注发布于 2025-02-26 10:35:09发布于 2025-02-26 '
#  '10:35:0983.6K17举报文章被收录于专栏：AI代码助手官方活动AI代码助手官方活动你好，我是你的智能编码助手！上周，我们将 DeepSeek '
#  'R1 满血版的腾讯云AI代码助手内置到了微信开发者工具中，让微信小程序开发更简单。今天！我带着 DeepSeek R1 + '
#  '腾讯周边礼物来了即日起，只要在「 Visual Studio Code 、JetBrains IDEs、Visual Studio、微信开发者工具」任意 '
#  'IDE 中体验 DeepSeek 均有机会获奖，以下是活动详情。参与时间\xa02025年2月25日-2025年3月10日活动福利\xa0'
#  '福利一：人人有礼在B站/小红书/腾讯云开发者社区 /CSDN/今日头条等任何技术社区分享发布 tencent-deepseekR1 '
#  '模型使用体验，包括【#腾讯云AI代码助手#使用截图 + 不少于 30 字的体验心得】，并「@ 腾讯云 AI '
#  '代码助手」官方账号，保存分享截图，即可随机领取鹅厂周边，参与即可 100% 获奖~福利二：爆款加码！腾讯云 AI '
#  '代码助手官方将从上传截图的用户中每日再评选 3位 优质反馈用户（综合内容质量、转评赞数量评选），加赠腾讯定制周边露营桌(价值 300 '
#  '元)，并于每个工作日晚上 6 点在【公众号文章评论区+社群】公布中奖用户昵称参与方式首先下载安装/更新「腾讯云 AI '
# ...

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=1024,
    chunk_overlap=100,
    paragraph_separator="\n\n",
    secondary_chunking_regex="<table>(.+?)</table>"
)

nodes = splitter.get_nodes_from_documents(documentes)

# %%
for node in nodes:
    pprint(node.text)
# Out:
# ('Unnamed: 0: 办户类型, 不办理户口: 一, 异地办深户: 二, 办理户口: 三, 办理户口.1: 四, 办理户口.2: 五, 办理户口.3: '
#  '六, 办理户口.4: 七, 办理户口.5: 八, 办理户口.6: 九, 办理户口.7: 十, 办理户口.8: 十一, 办理户口.9: 十二\n'
#  'Unnamed: 0: 工作地点, 不办理户口: 不办户，且不是以下工作地点的：\n'
#  '西安户县、西安高新区、商洛、长沙、宁波保税区, 异地办深户: 本地区无办户条件，需办深户：\n'
#  '中山、汕尾、韶关、汕头、桂林、玉溪、贵阳、杭州、宁波奉化、淮安、吉林、承德、大连、安阳、北京、惠州、无为, 办理户口: 深圳坪山, 办理户口.1: '
#  '深圳坑梓, 办理户口.2: 深圳葵涌, 办理户口.3: 深圳宝龙, 办理户口.4: 长沙（经开区）, 办理户口.5: 长沙（雨花区）, 办理户口.6: '
#  '广安, 办理户口.7: 西安、商洛、包头、太原、银川、西宁南川、海东, 办理户口.8: 常州（户口待22年后进一步确认）, 办理户口.9: 合肥\n'
#  'Unnamed: 0: 三方填写信息, 不办理户口: 单位名称：比亚迪股份有限公司  \n'
#  '单位隶属：市科技局\n'
#  '组织机构代码：19231745-8     \n'
#  '单位性质：民营\n'
#  '社会信用代码：91440300192317458F\n'
#  '联系电话：0755-89888888-68666    \n'
#  '联系人：校园招聘小组       \n'
#  '公司邮政编码：518118\n'
#  '通讯地址：深圳市坪山区比亚迪路3009号                                                            '
#  '报到证抬头：不接收             \n'
#  '报到证地址：不接收                \n'
#  '户口迁移地址：不接收\n'
#  '户口迁移原因：不接收       \n'
#  '档案接收单位名称：不接收  \n'
# ...

# %% [markdown]
# ## 模型设置

# %% [markdown]
# !pip install llama-index-llms-openai-like

# %% [markdown]
# !pip install llama-index-embeddings-openai

# %% [markdown]
# !pip install llama-index-embeddings-openai-like

# %%
from llama_index.core import Settings
from llama_index.llms.openai_like import OpenAILike
from llama_index.embeddings.openai_like import OpenAILikeEmbedding

Settings.llm = OpenAILike(
    model="deepseek-chat",
    api_base="https://api.deepseek.com/beta",
    api_key="sk-5b959fe6f3794438a4196cabd7d929e8"
)
Settings.embed_model = OpenAILikeEmbedding(
    model_name="text-embedding-v3",
    api_base="https://dashscope.aliyuncs.com/compatible-mode/v1",
    api_key="sk-d97bb707eaec4049ae9e2818b32f080d"
)

# %% [markdown]
# !curl -v https://dashscope.aliyuncs.com/compatible-mode/v1/models \
#   -H "Authorization: Bearer sk-d97bb707eaec4049ae9e2818b32f080d"

# %% [markdown]
# ## 设置向量数据库

# %% [markdown]
# !pip install faiss-cpu

# %% [markdown]
# !pip install llama-index-vector-stores-faiss

# %%
import faiss
from llama_index.vector_stores.faiss import FaissVectorStore
from llama_index.core import StorageContext, VectorStoreIndex
# 创建Faiss索引
d = 1024    # text-embedding-v3模型默认是1024维度
faiss_index = faiss.IndexFlatL2(d)

#包装为llamaindex 的向量存储
vector_store = FaissVectorStore(faiss_index=faiss_index)

# 创建上下文存储
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# 构建最终的索引
index = VectorStoreIndex(nodes=nodes, storage_context=storage_context,show_progress=True)
# Out:
# ...
# Generating embeddings: 100%|██████████| 18/18 [00:01<00:00, 11.31it/s]

# %% [markdown]
# ## 创建向量检索器

# %%
from llama_index.core.retrievers import VectorIndexRetriever

retriever = VectorIndexRetriever(index=index, similarity_top_k=5)    # 设置召回的数量  

# 下面这种方式同样可以创建检索器
# retriever = index.as_retriever()

# %% [markdown]
# ## 创建查询引擎

# %%
from llama_index.core.query_engine import RetrieverQueryEngine

query_engine = RetrieverQueryEngine.from_args(retriever=retriever)

# %% [markdown]
# ## 执行查询

# %%
response = query_engine.query("我要给坪山比亚迪寄档案，我要联系谁， 电话是多少。")
print(response)
# Out:
# 2026-01-29 21:52:13,695 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-29 21:52:14,181 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-29 21:52:16,153 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 根据上下文信息，如果您要给坪山比亚迪寄档案，需要联系坪山档案窗口值班负责人（比亚迪来档），联系电话是0755-85208603。

# %% [markdown]
# ## 查看检索节点

# %%
retriever_nodes = retriever.retrieve("我要给坪山比亚迪寄档案，我要联系谁， 电话是多少。")

len(retriever_nodes)
# Out:
# 2026-01-30 10:11:02,335 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 5

# %%
for i, node in enumerate(retriever_nodes):
    print(f"节点{i+1}")
    print(f"相似度得分：{node.score}")
    print(f"节点内容：{node.text}")
    print('-'*50)
# Out:
# 节点1
# 相似度得分：0.432256817817688
# 节点内容：单位名称：比亚迪股份有限公司
# 单位隶属：市科技局
# 组织机构代码：19231745-8
# 单位性质：民营
# 社会信用代码：91440300192317458F
# 联系电话：0755-89888888-68666
# 联系人：校园招聘小组
# 公司邮政编码：518118
# 通讯地址：深圳市坪山区比亚迪路3009号
# 报到证抬头：【填写以下其中一项都可】
# 深圳市人力资源和社会保障局/比亚迪股份有限公司
# 报到证地址：广东省深圳市
# 户口迁移地址：广东省深圳市大鹏新区延安路1号
# 户口迁移原因：大中专学生毕业
# 户口迁入地派出所全称： 深圳市公安局大鹏分局葵冲派出所
# 档案接收单位名称：深圳市大鹏新区人力资源服务中心
# 档案接收单位地址：深圳市大鹏新区金业大道深圳国际生物谷生命科学产业园B8栋1楼
# 档案接收邮政编码：518119
# 档案联系人：魏先生
# 档案联系电话：0755-28333161
# 档案邮寄方式: 学校以机要方式或EMS邮寄，不可自带     , 办理户口: 单位名称：比亚迪汽车工业有限公司
# 单位隶属：市科技局
# 组织机构代码：79173855-3
# 单位性质：民营
# 社会信用代码：91440300791738553L
# 联系电话：0755-89888888-68666
# 联系人：校园招聘小组
# 公司邮政编码：518118
# 通讯地址：深圳市坪山区比亚迪路3009号
# 报到证抬头：【填写以下其中一项都可】深圳市人力资源和社会保障局/比亚迪汽车工业有限公司
# 报到证地址：广东省深圳市
# 户口迁移证地址：广东省深圳市坪山区坪山比亚迪路3001号
# 户口迁移原因：大中专学生毕业或者毕业生入户
# 档案接收单位名称：深圳市坪山区劳动就业技能培训中心
# 档案接收单位地址：广东省深圳市坪山区金牛西路12号坪山区行政服务大厅六楼
# 档案接收邮政编码：518118
# 档案联系人：坪山档案窗口值班负责人（比亚迪来档）
# 档案联系电话：0755-85208603
# 档案邮寄方式：学校以机要方式或EMS邮寄,不允许自带、不允许自己邮寄
# ...

# %%
response_test1 = query_engine.query("James是谁")
print(response_test1)
# Out:
# 2026-01-30 13:31:25,644 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-30 13:31:25,931 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-30 13:31:27,539 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 根据提供的信息，没有提到任何名为James的人。

# %%
retriever_nodes2 = retriever.retrieve("James是谁")
print(retriever_nodes2[0].score)
# Out:
# 2026-01-30 13:31:31,694 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 1.368686318397522

# %%
attr_list = [attr for attr in dir(query_engine.get_prompts()['response_synthesizer:refine_template']) if not attr.startswith('_')]
print("查询引擎的主要属性:", attr_list)
print("="*50)
# Out:
# 查询引擎的主要属性: ['conditionals', 'construct', 'copy', 'default_template', 'dict', 'format', 'format_messages', 'from_orm', 'function_mappings', 'get_template', 'json', 'kwargs', 'metadata', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'output_parser', 'parse_file', 'parse_obj', 'parse_raw', 'partial_format', 'schema', 'schema_json', 'select', 'template_var_mappings', 'template_vars', 'update_forward_refs', 'validate']
# ...

# %%
# 3. 检查响应合成器使用的提示词模板（这是关键！）
from llama_index.core.prompts import PromptTemplate
# 根据你的合成器类型，可能需要这样查看
print(hasattr(query_engine, 'response_synthesizer'))
prompt_template = query_engine.get_prompts()
if prompt_template:
    print("使用的提示词模板:")
    print(prompt_template['response_synthesizer:refine_template'])
    print('-'*50)
    print(prompt_template['response_synthesizer:text_qa_template'])
# Out:
# False
# 使用的提示词模板:
# ...

# %%
metadata={'prompt_type': <PromptType.REFINE: 'refine'>} 
template_vars=['query_str', 'existing_answer', 'context_msg'] 
kwargs={} 
output_parser=None 
template_var_mappings={} 
function_mappings={} 
default_template=PromptTemplate(
    metadata={'prompt_type': <PromptType.REFINE: 'refine'>}, 
    template_vars=['query_str', 'existing_answer', 'context_msg'], 
    kwargs={}, output_parser=None, 
    template_var_mappings=None, 
    function_mappings=None, 
    template="The original query is as follows: {query_str}\nWe have provided an existing answer: {existing_answer}\nWe have the opportunity to refine the existing answer (only if needed) with some more context below.\n------------\n{context_msg}\n------------\nGiven the new context, refine the original answer to better answer the query. If the context isn't useful, return the original answer.\nRefined Answer: ") 
conditionals=[
    (
        <function is_chat_model at 0x7f529a118540>, 
        ChatPromptTemplate(
            metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, 
            template_vars=['context_msg', 'query_str', 'existing_answer'], 
            kwargs={}, 
            output_parser=None, 
            template_var_mappings=None, 
            function_mappings=None, 
            message_templates=[
                ChatMessage(
                    role=<MessageRole.USER: 'user'>, 
                    additional_kwargs={}, 
                    blocks=[
                        TextBlock(
                            block_type='text', 
                            text="You are an expert Q&A system that strictly operates in two modes when refining existing answers:\n1. **Rewrite** an original answer using the new context.\n2. **Repeat** the original answer if the new context isn't useful.\nNever reference the original answer or context directly in your answer.\nWhen in doubt, just repeat the original answer.\nNew Context: {context_msg}\nQuery: {query_str}\nOriginal Answer: {existing_answer}\nNew Answer: "
                        )])]))]

# %%
metadata={'prompt_type': <PromptType.QUESTION_ANSWER: 'text_qa'>} 
template_vars=['context_str', 'query_str'] 
kwargs={} 
output_parser=None 
template_var_mappings={} 
function_mappings={} 
default_template=PromptTemplate(
    metadata={'prompt_type': <PromptType.QUESTION_ANSWER: 'text_qa'>}, 
    template_vars=['context_str', 'query_str'], 
    kwargs={}, 
    output_parser=None, 
    template_var_mappings=None, 
    function_mappings=None, 
    template='Context information is below.\n---------------------\n{context_str}\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: {query_str}\nAnswer: ') 
conditionals=[
    (
        <function is_chat_model at 0x7f529a118540>, 
        ChatPromptTemplate(
            metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, 
            template_vars=['context_str', 'query_str'], 
            kwargs={}, 
            output_parser=None, 
            template_var_mappings=None, 
            function_mappings=None, 
            message_templates=[
                ChatMessage(
                    role=<MessageRole.SYSTEM: 'system'>, 
                    additional_kwargs={}, 
                    blocks=[
                        TextBlock(
                            block_type='text', 
                            text="You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."
                        )
                    ]
                ), 
                ChatMessage(
                    role=<MessageRole.USER: 'user'>, 
                    additional_kwargs={}, 
                    blocks=[
                        TextBlock(
                            block_type='text', 
                            text='Context information is below.\n---------------------\n{context_str}\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: {query_str}\nAnswer: '
                        )
                    ]
                )
            ]
))]

# %%
response_test2 = query_engine.query("可以告诉我更多吗")
print(response_test2)
# Out:
# 2026-01-30 10:20:18,814 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-30 10:20:19,319 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-30 10:20:20,050 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 根据您提供的上下文信息，这里整理了比亚迪汽车工业有限公司（深圳）、常州比亚迪汽车有限公司和合肥比亚迪汽车有限公司的相关信息，包括档案接收、报到证、户口迁移等具体内容。如果您需要了解特定公司的详细信息，请告知具体公司名称，我可以为您提供更详细的指引。

# %% [markdown]
# 'from_defaults(retriever: BaseRetriever, chat_history: Optional[List[ChatMessage]] = None, memory: Optional[BaseMemory] = None, system_prompt: Optional[str] = None, prefix_messages: Optional[List[ChatMessage]] = None, node_postprocessors: Optional[List[BaseNodePostprocessor]] = None, context_template: Optional[Union[str, PromptTemplate]] = None, context_refine_template: Optional[Union[str, PromptTemplate]] = None, llm: Optional[LLM] = None, **kwargs: Any) -> ContextChatEngine'

# %%
from llama_index.core.memory import Memory
from llama_index.core.chat_engine import ContextChatEngine


memory = Memory.from_defaults(
    session_id="my_session",
    token_limit=5000,
    chat_history_token_ratio=0.8
)
chat_engine = ContextChatEngine.from_defaults(
    memory=memory,
    retriever=retriever,
    system_prompt=(
        "你是一个聊天机器人"
        "你要基于检索回来的消息回答问题，如果没有检索回来消息，根据你自身的能力回答，不要不回答问题"
    )  
)
# response = chat_engine.stream_chat("James 是谁")
# for token in response.response_gen:
#     print(token, end = "")

response1 = chat_engine.chat("詹姆斯是谁")
response2 = chat_engine.chat("我要给坪山比亚迪寄档案，我要联系谁， 电话是多少")
response3 = chat_engine.chat("那长沙比亚迪呢")
print(response1)
print('-'*50)
print(response2)
print('-'*50)
print(response3)
print('-'*50)
# Out:
# 2026-01-30 11:53:59,174 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-30 11:53:59,522 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-30 11:54:04,282 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-30 11:54:09,272 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-30 11:54:09,451 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-30 11:54:12,654 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# 2026-01-30 11:54:18,699 - INFO - HTTP Request: POST https://dashscope.aliyuncs.com/compatible-mode/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-30 11:54:18,837 - INFO - HTTP Request: POST https://api.deepseek.com/beta/completions "HTTP/1.1 200 OK"
# ...
